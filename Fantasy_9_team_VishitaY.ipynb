# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishita7/Decision-Modelling-Optimization/blob/main/Fantasy_9_team_VishitaY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fantasy Team Creation Project**
#
# This project focuses on utilizing linear optimization techniques to create an optimal fantasy team for a given budget and set of constraints. The goal is to select a team of players from a pool of available options that maximizes the expected points while adhering to various constraints such as budget limitations and position requirements.
#
# **Project Overview**
#
# The objective of this project is to leverage linear integer optimization algorithms to create a fantasy team that maximizes the total expected points within the constraints of a predefined budget and position requirements. By formulating the problem as a linear programming model, we aim to find an optimal combination of players that provides the highest expected performance while staying within the specified budget and fulfilling position-specific requirements.
#
# **Key Features**
#
# **Linear Optimization:** The project utilizes linear optimization techniques to solve the fantasy team selection problem. By formulating the problem as a integer programming model, the code aims to find the best combination of players that maximize the expected points while adhering to the given constraints.
#
# **Budget Constraint:** The project incorporates a budget constraint, ensuring that the total cost of the selected players does not exceed the available budget. This constraint ensures that the team remains within the budget limitations while aiming to maximize the expected points.
#
# **Position Constraints:** The project also takes into account position-specific constraints. These constraints specify the required number of players for each position (e.g., quarterback, running back, wide receiver) in the fantasy team. By including position constraints, the code ensures that the team composition aligns with the desired lineup structure.
#
# **Usage**
# To utilize the fantasy team creation code, follow these steps:
#
# Provide the player dataset: Prepare a dataset containing player information, including their positions, expected points, and costs. Ensure the dataset is structured appropriately for the code to extract the necessary information.
#
# Set the budget and constraints: Define the budget available for selecting players and specify the position constraints (e.g., the required number of players for each position) according to your fantasy team requirements.
#
# Execute the code: Run the provided code to create an optimal fantasy team. The code utilizes linear optimization techniques to find the combination of players that maximizes the expected points while adhering to the specified budget and position constraints.
#
# Review the results: Examine the output of the code, which includes the selected players for the fantasy team, the total expected points, and the total cost. Analyze these results to assess the composition and performance of the generated team.

# %%
#import IDAES peckage and Libraries
import sys
import os
 
if 'google.colab' in sys.modules:
    # !pip install idaes-pse --pre
    # !idaes get-extensions --to ./bin
    os.environ['PATH'] += ':bin'

from pyomo.environ import *
import numpy as np
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting idaes-pse
#   Downloading idaes_pse-2.0.0-py3-none-any.whl (46.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (1.22.4)
# Collecting omlt==1.1
#   Downloading omlt-1.1-py2.py3-none-any.whl (37 kB)
# Collecting pandas<1.5
#   Downloading pandas-1.4.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 19.7 MB/s eta 0:00:00
# Collecting flask-cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (8.1.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (1.11.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (6.5.4)
# Collecting backports.shutil-get-terminal-size
#   Downloading backports.shutil_get_terminal_size-1.0.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: flask in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (2.2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (5.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (2.27.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (1.10.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (7.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (3.7.1)
# Collecting distro
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (8.0.1)
# Collecting pyomo>=6.5.0
#   Downloading Pyomo-6.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 14.8 MB/s eta 0:00:00
# Collecting bunch
#   Downloading bunch-1.0.1.zip (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rbfopt
#   Downloading rbfopt-4.2.5-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (6.0)
# Collecting tinydb
#   Downloading tinydb-4.7.1-py3-none-any.whl (24 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (3.0.10)
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting pint
#   Downloading Pint-0.20.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.5/269.5 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (5.8.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (3.1)
# Requirement already satisfied: ipython<8.0.0 in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (7.34.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.9/dist-packages (from idaes-pse) (2.0.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (67.7.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (0.1.6)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (2.14.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (3.0.38)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython<8.0.0->idaes-pse) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.5->idaes-pse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<1.5->idaes-pse) (2022.7.1)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from flask->idaes-pse) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from flask->idaes-pse) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from flask->idaes-pse) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from flask->idaes-pse) (6.6.0)
# Requirement already satisfied: Six in /usr/local/lib/python3.9/dist-packages (from flask-cors->idaes-pse) (1.16.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from jupyter->idaes-pse) (5.5.6)
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from jupyter->idaes-pse) (6.4.8)
# Collecting qtconsole
#   Downloading qtconsole-5.4.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from jupyter->idaes-pse) (7.7.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter->idaes-pse) (6.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->idaes-pse) (1.4.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (0.7.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (6.0.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (0.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (4.11.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (5.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (2.1.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->idaes-pse) (0.2.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->idaes-pse) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->idaes-pse) (2.16.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/dist-packages (from openpyxl->idaes-pse) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest->idaes-pse) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest->idaes-pse) (1.0.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest->idaes-pse) (2.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->idaes-pse) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from pytest->idaes-pse) (23.1.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->idaes-pse) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->idaes-pse) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->idaes-pse) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->idaes-pse) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->idaes-pse) (1.26.15)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->idaes-pse) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->flask->idaes-pse) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython<8.0.0->idaes-pse) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->idaes-pse) (0.19.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.7->nbconvert->idaes-pse) (3.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.9/dist-packages (from nbclient>=0.5.0->nbconvert->idaes-pse) (6.1.12)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython<8.0.0->idaes-pse) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0->idaes-pse) (0.2.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->idaes-pse) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->idaes-pse) (0.5.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter->idaes-pse) (0.2.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter->idaes-pse) (6.2)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter->idaes-pse) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter->idaes-pse) (3.0.7)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->idaes-pse) (23.2.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->idaes-pse) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->idaes-pse) (0.16.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->idaes-pse) (1.5.6)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->idaes-pse) (0.17.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->idaes-pse) (21.3.0)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->jupyter->idaes-pse) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->idaes-pse) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->idaes-pse) (2.21)
# Building wheels for collected packages: bunch
#   Building wheel for bunch (setup.py) ... done
#   Created wheel for bunch: filename=bunch-1.0.1-py3-none-any.whl size=7093 sha256=8dcdafd3a262d435400c237b9a66cf2d63a059607863652152eac70e8da384ad
#   Stored in directory: /root/.cache/pip/wheels/11/74/ab/9e0b2f78868620864edf9bc755e67fc3ecb0f1371912db869b
# Successfully built bunch
# Installing collected packages: ply, bunch, backports.shutil-get-terminal-size, tinydb, qtpy, pyomo, pint, jedi, distro, colorama, rbfopt, pandas, omlt, flask-cors, qtconsole, jupyter, idaes-pse
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 1.4.4 which is incompatible.
# Successfully installed backports.shutil-get-terminal-size-1.0.0 bunch-1.0.1 colorama-0.4.6 distro-1.8.0 flask-cors-3.0.10 idaes-pse-2.0.0 jedi-0.18.2 jupyter-1.0.0 omlt-1.1 pandas-1.4.4 pint-0.20.1 ply-3.11 pyomo-6.5.0 qtconsole-5.4.2 qtpy-2.3.1 rbfopt-4.2.5 tinydb-4.7.1
# Getting files...
# Done
# ---------------------------------------------------
# IDAES Extensions Build Versions
# ===================================================
# Solvers:  vno version file found
# Library:  vno version file found
# ===================================================

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#input data
path_to_input = "/content/drive/__/NFL_2020-12-20_DK_12_20-100PM-11-games-Main .csv"
input_data = pd.read_csv(path_to_input)

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 50 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DFS ID               449 non-null    int64
#  1   Name                 449 non-null    object
#  2   Pos                  449 non-null    object
#  3   Team                 449 non-null    object
#  4   Opp                  449 non-null    object
#  5   Status               144 non-null    object
#  6   Salary               449 non-null    int64
#  7   Actual               216 non-null    float64
#  8   SS Proj              254 non-null    float64
#  9   My Proj              449 non-null    float64
#  10  Value                449 non-null    float64
#  11  SS Own               449 non-null    float64
#  12  My Own               449 non-null    float64
#  13  Min Exp              0 non-null      float64
#  14  Max Exp              0 non-null      float64
#  15  dk_points            254 non-null    float64
#  16  dk_25_percentile     254 non-null    float64
#  17  dk_50_percentile     254 non-null    float64
#  18  dk_75_percentile     254 non-null    float64
#  19  dk_85_percentile     254 non-null    float64
#  20  dk_95_percentile     254 non-null    float64
#  21  dk_99_percentile     254 non-null    float64
#  22  fd_points            254 non-null    float64
#  23  fd_25_percentile     254 non-null    float64
#  24  fd_50_percentile     254 non-null    float64
#  25  fd_75_percentile     254 non-null    float64
#  26  fd_85_percentile     254 non-null    float64
#  27  fd_95_percentile     254 non-null    float64
#  28  fd_99_percentile     254 non-null    float64
#  29  yahoo_points         254 non-null    float64
#  30  yahoo_25_percentile  254 non-null    float64
#  31  yahoo_50_percentile  254 non-null    float64
#  32  yahoo_75_percentile  254 non-null    float64
#  33  yahoo_85_percentile  254 non-null    float64
#  34  yahoo_95_percentile  254 non-null    float64
#  35  yahoo_99_percentile  254 non-null    float64
#  36  dk_std               254 non-null    float64
#  37  fd_std               254 non-null    float64
#  38  yahoo_std            254 non-null    float64
#  39  Pass Att             254 non-null    float64
#  40  Completions          254 non-null    float64
#  41  Pass Yds             254 non-null    float64
#  42  Pass TD              254 non-null    float64
#  43  Pass Int             254 non-null    float64
#  44  Rec                  254 non-null    float64
#  45  Rec Yds              254 non-null    float64
#  46  Rec TD               254 non-null    float64
#  47  Rush Att             254 non-null    float64
#  48  Rush Yds             254 non-null    float64
#  49  Rush TD              254 non-null    float64
# dtypes: float64(43), int64(2), object(5)
# memory usage: 175.5+ KB

# %%
#check for missing values in data
missing_values = input_data.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  DFS ID                   0
# Name                     0
# Pos                      0
# Team                     0
# Opp                      0
# Status                 305
# Salary                   0
# Actual                 233
# SS Proj                195
# My Proj                  0
# Value                    0
# SS Own                   0
# My Own                   0
# Min Exp                449
# Max Exp                449
# dk_points              195
# dk_25_percentile       195
# dk_50_percentile       195
# dk_75_percentile       195
# dk_85_percentile       195
# dk_95_percentile       195
# dk_99_percentile       195
# fd_points              195
# fd_25_percentile       195
# fd_50_percentile       195
# fd_75_percentile       195
# fd_85_percentile       195
# fd_95_percentile       195
# fd_99_percentile       195
# yahoo_points           195
# yahoo_25_percentile    195
# yahoo_50_percentile    195
# yahoo_75_percentile    195
# yahoo_85_percentile    195
# yahoo_95_percentile    195
# yahoo_99_percentile    195
# dk_std                 195
# fd_std                 195
# yahoo_std              195
# Pass Att               195
# Completions            195
# Pass Yds               195
# Pass TD                195
# Pass Int               195
# Rec                    195
# Rec Yds                195
# Rec TD                 195
# Rush Att               195
# Rush Yds               195
# Rush TD                195
# dtype: int64

# %%
# imputing missing values  in SS Proj
mean_proj = input_data['SS Proj'].mean()
input_data['SS Proj'].fillna(mean_proj, inplace=True)
missing_values = input_data.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  DFS ID                   0
# Name                     0
# Pos                      0
# Team                     0
# Opp                      0
# Status                 305
# Salary                   0
# Actual                 233
# SS Proj                  0
# My Proj                  0
# Value                    0
# SS Own                   0
# My Own                   0
# Min Exp                449
# Max Exp                449
# dk_points              195
# dk_25_percentile       195
# dk_50_percentile       195
# dk_75_percentile       195
# dk_85_percentile       195
# dk_95_percentile       195
# dk_99_percentile       195
# fd_points              195
# fd_25_percentile       195
# fd_50_percentile       195
# fd_75_percentile       195
# fd_85_percentile       195
# fd_95_percentile       195
# fd_99_percentile       195
# yahoo_points           195
# yahoo_25_percentile    195
# yahoo_50_percentile    195
# yahoo_75_percentile    195
# yahoo_85_percentile    195
# yahoo_95_percentile    195
# yahoo_99_percentile    195
# dk_std                 195
# fd_std                 195
# yahoo_std              195
# Pass Att               195
# Completions            195
# Pass Yds               195
# Pass TD                195
# Pass Int               195
# Rec                    195
# Rec Yds                195
# Rec TD                 195
# Rush Att               195
# Rush Yds               195
# Rush TD                195
# dtype: int64

# %%
# Filter player data based on positions
n_players = len(input_data)
# Number of QB players
qb_data = input_data[input_data["Pos"].str.contains("QB")]
n_qb = len(qb_data)
# Number of RB players
rb_data = input_data[input_data["Pos"].str.contains("RB")]
n_rb = len(rb_data)
# Number of WR players
wr_data = input_data[input_data["Pos"].str.contains("WR")]
n_wr = len(wr_data)
# Number of TE players
te_data = input_data[input_data["Pos"].str.contains("TE")]
n_te = len(te_data)
# Number of DST players
dst_data = input_data[input_data["Pos"].str.contains("DST")]
n_dst = len(dst_data)
# Number of FLEX players(RB, WR, TE, FLEX)
flex_data = input_data[input_data["Pos"].str.contains("RB|WR|TE|FLEX")]
n_flex = len(flex_data)
# Print the number of players for each position
print(n_qb,'\t',n_rb,'\t',n_wr,'\t',n_te,'\t',n_dst,'\t',n_flex)
# Out:
# 60 	 112 	 159 	 96 	 22 	 367

# %%
# Number of players per position
positions = {
    "QB": 1,
    "RB": 2,
    "WR": 3,
    "TE": 1,
    "DST": 1,
    "FLEX": 1
}

# Create a concrete model
model = ConcreteModel()

# Define binary variable for each position
model.qb = Var(range(n_qb), within=Binary)
model.rb = Var(range(n_rb), within=Binary)
model.wr = Var(range(n_wr), within=Binary)
model.te = Var(range(n_te), within=Binary)
model.dst = Var(range(n_dst), within=Binary)
model.flex = Var(range(n_flex), within=Binary)

# Define Objective
objective_expr = 0
for i in range(n_qb):
    objective_expr += model.qb[i] * qb_data.iloc[i]["SS Proj"]
for i in range(n_rb):
    objective_expr += model.rb[i] * rb_data.iloc[i]["SS Proj"]
for i in range(n_wr):
    objective_expr += model.wr[i] * wr_data.iloc[i]["SS Proj"]
for i in range(n_te):
    objective_expr += model.te[i] * te_data.iloc[i]["SS Proj"]
for i in range(n_dst):
    objective_expr += model.dst[i] * dst_data.iloc[i]["SS Proj"]
for i in range(n_flex):
    objective_expr += model.flex[i] * flex_data.iloc[i]["SS Proj"]

model.total_points = Objective(expr=objective_expr, sense=maximize)

# ADD Constarints
## Total player count constraint (9 players in the lineup)
model.nplayers_constraint = Constraint(expr=(
    sum(model.qb[i] for i in range(n_qb)) +
    sum(model.rb[i] for i in range(n_rb)) +
    sum(model.wr[i] for i in range(n_wr)) +
    sum(model.te[i] for i in range(n_te)) +
    sum(model.dst[i] for i in range(n_dst)) +
    sum(model.flex[i] for i in range(n_flex))
    == 9
))

# constraints for each player and position
for pos, count in positions.items():
    if pos == "QB":
        model.qb_constraint = Constraint(expr=(sum(model.qb[i] for i in range(n_qb)) == count))
    elif pos == "RB":
        model.rb_constraint = Constraint(expr=(sum(model.rb[i] for i in range(n_rb)) == count))
    elif pos == "WR":
        model.wr_constraint = Constraint(expr=(sum(model.wr[i] for i in range(n_wr)) == count))
    elif pos == "TE":
        model.te_constraint = Constraint(expr=(sum(model.te[i] for i in range(n_te)) == count))
    elif pos == "DST":
        model.dst_constraint = Constraint(expr=(sum(model.dst[i] for i in range(n_dst)) == count))
    elif pos == "FLEX":
        model.flex_constraint = Constraint(expr=(sum(model.flex[i] for i in range(n_flex)) == count))

# Team Salary constraint
salary_expr = 0
for i in range(n_qb):
    salary_expr += model.qb[i] * qb_data.iloc[i]["Salary"]
for i in range(n_rb):
    salary_expr += model.rb[i] * rb_data.iloc[i]["Salary"]
for i in range(n_wr):
    salary_expr += model.wr[i] * wr_data.iloc[i]["Salary"]
for i in range(n_te):
    salary_expr += model.te[i] * te_data.iloc[i]["Salary"]
for i in range(n_dst):
    salary_expr += model.dst[i] * dst_data.iloc[i]["Salary"]
for i in range(n_flex):
    salary_expr += model.flex[i] * flex_data.iloc[i]["Salary"]

model.salary_constraint = Constraint(expr=salary_expr <= 50000)

# %%
#Solve using the 'cbc' solver
SolverFactory('cbc').solve(model, tee=True).write()
#Solve using the 'glpk' solver
#SolverFactory('glpk').solve(model, tee=True).write()
#SolverFactory('couenne').solve(model, tee=True).write()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Feb  3 2023
#
# command line - /content/bin/cbc -printingOptions all -import /tmp/tmpz2ps7ybi.pyomo.lp -stat=1 -solve -solu /tmp/tmpz2ps7ybi.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
#  CoinLpIO::readLp(): Maximization problem reformulated as minimization
# Coin0009I Switching back to maximization to get correct duals etc
# Presolve 7 (-2) rows, 816 (-1) columns and 1632 (-817) elements
# Statistics for presolved model
# Original problem has 816 integers (816 of which binary)
# Presolved problem has 816 integers (816 of which binary)
# ==== 4 zero objective 254 different
# ==== absolute objective values 254 different
# ==== for integers 4 zero objective 254 different
# ==== for integers absolute objective values 254 different
# ===== end objective counts
#
#
# Problem has 7 rows, 816 columns (812 with objective) and 1632 elements
# Column breakdown:
# 0 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 816 of type 0.0->1.0
# Row breakdown:
# 0 of type E 0.0, 4 of type E 1.0, 0 of type E -1.0,
# 2 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 0 of type L 0.0, 0 of type L 1.0,
# 1 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 168.332 - 0.00 seconds
# Cgl0004I processed model has 8 rows, 250 columns (250 integer (247 of which binary)) and 750 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.363636
# Cbc0038I Solution found of -167.572
# Cbc0038I Cleaned solution of -167.572
# Cbc0038I Before mini branch and bound, 248 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8 rows 250 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -167.648
# Cbc0038I Reduced cost fixing fixed 231 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.01476 (2) obj. -167.648 iterations 3
# Cbc0038I Pass   2: suminf.    0.14286 (2) obj. -168.308 iterations 5
# Cbc0038I Pass   3: suminf.    0.77419 (2) obj. -167.761 iterations 3
# Cbc0038I Pass   4: suminf.    0.40258 (2) obj. -167.648 iterations 5
# Cbc0038I Pass   5: suminf.    0.42857 (2) obj. -167.782 iterations 5
# Cbc0038I Pass   6: suminf.    0.63636 (2) obj. -167.826 iterations 6
# Cbc0038I Pass   7: suminf.    0.23802 (2) obj. -167.648 iterations 5
# Cbc0038I Pass   8: suminf.    0.25000 (2) obj. -167.71 iterations 5
# Cbc0038I Pass   9: suminf.    0.50000 (2) obj. -168.19 iterations 5
# Cbc0038I Pass  10: suminf.    0.01476 (2) obj. -167.648 iterations 5
# Cbc0038I Pass  11: suminf.    0.14286 (2) obj. -168.308 iterations 5
# Cbc0038I Pass  12: suminf.    0.36364 (2) obj. -168.332 iterations 3
# Cbc0038I Pass  13: suminf.    0.51034 (3) obj. -167.648 iterations 7
# Cbc0038I Pass  14: suminf.    0.40258 (2) obj. -167.648 iterations 2
# Cbc0038I Pass  15: suminf.    0.42857 (2) obj. -167.782 iterations 5
# Cbc0038I Pass  16: suminf.    0.99201 (2) obj. -167.648 iterations 4
# Cbc0038I Pass  17: suminf.    0.36364 (2) obj. -168.332 iterations 4
# Cbc0038I Pass  18: suminf.    0.36364 (2) obj. -168.332 iterations 3
# Cbc0038I Pass  19: suminf.    0.90909 (2) obj. -167.855 iterations 4
# Cbc0038I Pass  20: suminf.    0.90909 (2) obj. -167.855 iterations 2
# Cbc0038I Pass  21: suminf.    0.90909 (2) obj. -167.855 iterations 0
# Cbc0038I Pass  22: suminf.    0.90909 (2) obj. -167.855 iterations 0
# Cbc0038I Pass  23: suminf.    0.90909 (2) obj. -167.855 iterations 2
# Cbc0038I Pass  24: suminf.    0.90909 (2) obj. -167.855 iterations 2
# Cbc0038I Pass  25: suminf.    0.63636 (2) obj. -167.826 iterations 6
# Cbc0038I Pass  26: suminf.    0.23802 (2) obj. -167.648 iterations 6
# Cbc0038I Pass  27: suminf.    0.25000 (2) obj. -167.71 iterations 5
# Cbc0038I Pass  28: suminf.    0.23802 (2) obj. -167.648 iterations 3
# Cbc0038I Pass  29: suminf.    0.23802 (2) obj. -167.648 iterations 1
# Cbc0038I Pass  30: suminf.    0.95387 (4) obj. -167.648 iterations 5
# Cbc0038I Before mini branch and bound, 241 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8 rows 250 columns, reduced to 2 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -167.785
# Cbc0038I Reduced cost fixing fixed 231 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.04132 (2) obj. -167.785 iterations 0
# Cbc0038I Pass  31: suminf.    0.14286 (2) obj. -168.308 iterations 4
# Cbc0038I Pass  32: suminf.    0.36364 (2) obj. -168.332 iterations 5
# Cbc0038I Pass  33: suminf.    0.36364 (2) obj. -168.332 iterations 1
# Cbc0038I Pass  34: suminf.    0.50000 (2) obj. -168.19 iterations 8
# Cbc0038I Pass  35: suminf.    0.10182 (2) obj. -167.785 iterations 6
# Cbc0038I Pass  36: suminf.    0.04132 (2) obj. -167.785 iterations 3
# Cbc0038I Pass  37: suminf.    0.94254 (2) obj. -167.785 iterations 7
# Cbc0038I Pass  38: suminf.    0.90909 (2) obj. -167.855 iterations 5
# Cbc0038I Pass  39: suminf.    0.43274 (3) obj. -167.785 iterations 8
# Cbc0038I Pass  40: suminf.    0.72727 (2) obj. -167.993 iterations 4
# Cbc0038I Pass  41: suminf.    0.63636 (2) obj. -167.826 iterations 3
# Cbc0038I Pass  42: suminf.    0.36503 (3) obj. -167.785 iterations 6
# Cbc0038I Pass  43: suminf.    0.36503 (3) obj. -167.785 iterations 0
# Cbc0038I Pass  44: suminf.    0.36503 (3) obj. -167.785 iterations 0
# Cbc0038I Pass  45: suminf.    0.36503 (3) obj. -167.785 iterations 2
# Cbc0038I Pass  46: suminf.    1.00000 (2) obj. -167.809 iterations 6
# Cbc0038I Pass  47: suminf.    1.00000 (2) obj. -167.809 iterations 2
# Cbc0038I Pass  48: suminf.    0.43274 (3) obj. -167.785 iterations 7
# Cbc0038I Pass  49: suminf.    0.72727 (2) obj. -167.993 iterations 4
# Cbc0038I Pass  50: suminf.    0.10182 (2) obj. -167.785 iterations 7
# Cbc0038I Pass  51: suminf.    0.04132 (2) obj. -167.785 iterations 3
# Cbc0038I Pass  52: suminf.    0.14286 (2) obj. -168.308 iterations 4
# Cbc0038I Pass  53: suminf.    0.09464 (2) obj. -167.785 iterations 4
# Cbc0038I Pass  54: suminf.    0.04132 (2) obj. -167.785 iterations 3
# Cbc0038I Pass  55: suminf.    0.71346 (3) obj. -167.785 iterations 6
# Cbc0038I Pass  56: suminf.    0.36503 (3) obj. -167.785 iterations 4
# Cbc0038I Pass  57: suminf.    0.84052 (3) obj. -167.785 iterations 3
# Cbc0038I Pass  58: suminf.    0.43274 (3) obj. -167.785 iterations 2
# Cbc0038I Pass  59: suminf.    0.72727 (2) obj. -167.993 iterations 4
# Cbc0038I Before mini branch and bound, 241 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8 rows 250 columns, reduced to 2 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -167.949
# Cbc0038I Reduced cost fixing fixed 236 variables on major pass 4
# Cbc0038I Pass  59: suminf.    0.07320 (2) obj. -167.949 iterations 0
# Cbc0038I Pass  60: suminf.    0.14286 (2) obj. -168.308 iterations 3
# Cbc0038I Pass  61: suminf.    0.36364 (2) obj. -168.332 iterations 2
# Cbc0038I Pass  62: suminf.    0.07320 (2) obj. -167.949 iterations 5
# Cbc0038I Pass  63: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  64: suminf.    1.00000 (3) obj. -167.949 iterations 0
# Cbc0038I Pass  65: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  66: suminf.    1.00000 (3) obj. -167.949 iterations 0
# Cbc0038I Pass  67: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  68: suminf.    0.36364 (2) obj. -168.332 iterations 6
# Cbc0038I Pass  69: suminf.    0.07320 (2) obj. -167.949 iterations 4
# Cbc0038I Pass  70: suminf.    0.14286 (2) obj. -168.308 iterations 3
# Cbc0038I Pass  71: suminf.    0.07320 (2) obj. -167.949 iterations 2
# Cbc0038I Pass  72: suminf.    0.36364 (2) obj. -168.332 iterations 4
# Cbc0038I Pass  73: suminf.    0.36364 (2) obj. -168.332 iterations 1
# Cbc0038I Pass  74: suminf.    0.07320 (2) obj. -167.949 iterations 3
# Cbc0038I Pass  75: suminf.    1.00000 (3) obj. -167.949 iterations 5
# Cbc0038I Pass  76: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  77: suminf.    1.00000 (3) obj. -167.949 iterations 0
# Cbc0038I Pass  78: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  79: suminf.    1.00000 (3) obj. -167.949 iterations 0
# Cbc0038I Pass  80: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  81: suminf.    0.16000 (2) obj. -168.285 iterations 4
# Cbc0038I Pass  82: suminf.    0.07320 (2) obj. -167.949 iterations 3
# Cbc0038I Pass  83: suminf.    0.14286 (2) obj. -168.308 iterations 3
# Cbc0038I Pass  84: suminf.    1.00000 (3) obj. -167.949 iterations 4
# Cbc0038I Pass  85: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  86: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  87: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I Pass  88: suminf.    1.00000 (3) obj. -167.949 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 243 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8 rows 250 columns, reduced to 2 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -167.572 - took 0.04 seconds
# Cbc0012I Integer solution of -167.5724 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 5
# Cbc0013I At root node, 1 cuts changed objective from -168.33195 to -167.89582 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 12.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 2 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -167.5724, took 4 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 229 variables fixed on reduced cost
# Cuts at root node changed objective from -168.332 to -167.896
# Probing was tried 2 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                167.57240000
# Enumerated nodes:               0
# Total iterations:               4
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.10
#
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.11
#
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 167.5724
#   Upper bound: 167.5724
#   Number of objectives: 1
#   Number of constraints: 7
#   Number of variables: 816
#   Number of binary variables: 816
#   Number of integer variables: 816
#   Number of nonzeros: 812
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   User time: -1.0
#   System time: 0.07
#   Wallclock time: 0.11
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#     Black box:
#       Number of iterations: 4
#   Error rc: 0
#   Time: 0.17426824569702148
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
selected_team = pd.DataFrame(columns=['Position', 'Name', 'Team', 'Opponent', 'Projected Points', 'Salary'])

# Add selected players to the DataFrame
for position, var_list in [('QB', model.qb), ('RB', model.rb), ('WR', model.wr), ('TE', model.te), ('DST', model.dst), ('FLEX', model.flex)]:
    for i in range(len(var_list)):
        if var_list[i].value == 1:
            data = None
            if position == 'QB':
                data = qb_data.iloc[i]
            elif position == 'RB':
                data = rb_data.iloc[i]
            elif position == 'WR':
                data = wr_data.iloc[i]
            elif position == 'TE':
                data = te_data.iloc[i]
            elif position == 'DST':
                data = dst_data.iloc[i]
            elif position == 'FLEX':
                data = flex_data.iloc[i]

            selected_team = selected_team.append({
                'Position': position,
                'Name': data['Name'],
                'Team': data['Team'],
                'Opponent': data.get('Opp', ''),
                'Projected Points': data['SS Proj'],
                'Salary': data['Salary']
            }, ignore_index=True)

# Display the DataFrame as a table
print(f"Total points: {model.total_points()}")
print("Team_Selection:", '\n\n', selected_team, '\n\n')
# Out:
# Total points: 167.5724
# Team_Selection:
#
#    Position              Name Team Opponent  Projected Points Salary
# 0       QB      Kyler Murray  ARI      PHI           26.8949   7000
# 1       RB      Alvin Kamara   NO       KC           25.1607   7400
# 2       RB      Tony Pollard  DAL       SF           20.9832   5200
# 3       WR     Brandon Aiyuk   SF      DAL           17.5536   6300
# 4       WR  Emmanuel Sanders   NO       KC           15.5059   4200
# 5       WR    Tre'Quan Smith   NO       KC           11.9099   3200
# 6       TE      Travis Kelce   KC       NO           20.8680   8000
# 7      DST         Seahawks   SEA      WAS            7.7130   3100
# 8     FLEX      Tony Pollard  DAL       SF           20.9832   5200
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({
# <ipython-input-10-b3c027d4b43a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team = selected_team.append({

# %% [markdown]
# ##Adding Stacking Constraints

# %%
# Number of players per position
positions = {
    "QB": 1,
    "RB": 2,
    "WR": 3,
    "TE": 1,
    "DST": 1,
    "FLEX": 1
}
# Create Concrete Model
model1 = ConcreteModel()

# Define binary variables for each position
model1.qb = Var(range(n_qb), within=Binary)
model1.rb = Var(range(n_rb), within=Binary)
model1.wr = Var(range(n_wr), within=Binary)
model1.te = Var(range(n_te), within=Binary)
model1.dst = Var(range(n_dst), within=Binary)
model1.flex = Var(range(n_flex), within=Binary)

# Define Objective function
objective_expr = 0
for i in range(n_qb):
    objective_expr += model1.qb[i] * qb_data.iloc[i]["SS Proj"]
for i in range(n_rb):
    objective_expr += model1.rb[i] * rb_data.iloc[i]["SS Proj"]
for i in range(n_wr):
    objective_expr += model1.wr[i] * wr_data.iloc[i]["SS Proj"]
for i in range(n_te):
    objective_expr += model1.te[i] * te_data.iloc[i]["SS Proj"]
for i in range(n_dst):
    objective_expr += model1.dst[i] * dst_data.iloc[i]["SS Proj"]
for i in range(n_flex):
    objective_expr += model1.flex[i] * flex_data.iloc[i]["SS Proj"]

model1.total_points = Objective(expr=objective_expr, sense=maximize)

# Player count constraint
model1.n_players_constraint = Constraint(expr=(
    sum(model1.qb[i] for i in range(n_qb)) +
    sum(model1.rb[i] for i in range(n_rb)) +
    sum(model1.wr[i] for i in range(n_wr)) +
    sum(model1.te[i] for i in range(n_te)) +
    sum(model1.dst[i] for i in range(n_dst)) +
    sum(model1.flex[i] for i in range(n_flex))
    == 9
))

# Players per Position constraints
for pos, count in positions.items():
    if pos == "QB":
        model1.qb_constraint = Constraint(expr=(sum(model1.qb[i] for i in range(n_qb)) == count))
    elif pos == "RB":
        model1.rb_constraint = Constraint(expr=(sum(model1.rb[i] for i in range(n_rb)) == count))
    elif pos == "WR":
        model1.wr_constraint = Constraint(expr=(sum(model1.wr[i] for i in range(n_wr)) == count))
    elif pos == "TE":
        model1.te_constraint = Constraint(expr=(sum(model1.te[i] for i in range(n_te)) == count))
    elif pos == "DST":
        model1.dst_constraint = Constraint(expr=(sum(model1.dst[i] for i in range(n_dst)) == count))
    elif pos == "FLEX":
        model1.flex_constraint = Constraint(expr=(sum(model1.flex[i] for i in range(n_flex)) == count))

# Salary constraint
salary_expr = 0
for i in range(n_qb):
    salary_expr += model1.qb[i] * qb_data.iloc[i]["Salary"]
for i in range(n_rb):
    salary_expr += model1.rb[i] * rb_data.iloc[i]["Salary"]
for i in range(n_wr):
    salary_expr += model1.wr[i] * wr_data.iloc[i]["Salary"]
for i in range(n_te):
    salary_expr += model1.te[i] * te_data.iloc[i]["Salary"]
for i in range(n_dst):
    salary_expr += model1.dst[i] * dst_data.iloc[i]["Salary"]
for i in range(n_flex):
    salary_expr += model1.flex[i] * flex_data.iloc[i]["Salary"]

model1.salary_constraint = Constraint(expr=salary_expr <= 50000)

# Player count constraint
model1.nplayers_constraint = Constraint(expr=(
    sum(model1.qb[i] for i in range(n_qb)) +
    sum(model1.rb[i] for i in range(n_rb)) +
    sum(model1.wr[i] for i in range(n_wr)) +
    sum(model1.te[i] for i in range(n_te)) +
    sum(model1.dst[i] for i in range(n_dst)) +
    sum(model1.flex[i] for i in range(n_flex))
    == 9
))

# Stacking constraints
def stacking_constraints_rule(model1, i):
    # The team of the selected QB
    qb_team = qb_data.iloc[i]["Team"]

    # Count the number of WRs and TEs from the same team as the QB
    wr_on_same_team = 0
    for j in range(n_wr):
        if wr_data.iloc[j]["Team"] == qb_team:
            wr_on_same_team += model1.wr[j]

    te_on_same_team = 0
    for j in range(n_te):
        if te_data.iloc[j]["Team"] == qb_team:
            te_on_same_team += model1.te[j]

    total_te_wr_same_team = wr_on_same_team + te_on_same_team

    # Return at least 2 WRs or TEs from the QB's team are selected
    return model1.qb[i] * 2 <= total_te_wr_same_team

model1.stacking_constraints = Constraint(range(n_qb), rule=stacking_constraints_rule)


# Opposing DST constraint
def opp_dst_constraints_rule(model1, i):
    # Get the opponent team of the selected QB
    qb_opp = qb_data.iloc[i]["Opp"]
    
    # Check if any DST from the opponent team of the QB is selected
    opp_dst_selected=0
    for j in range(n_dst):
       if dst_data.iloc[j]["Team"] == qb_opp:
          opp_dst_selected += model1.dst[j]
    
    # Ensure that the selected QB's opponent DST is not selected
    return model1.qb[i] + opp_dst_selected <= 1

model1.opp_dst_constraints = Constraint(range(n_qb), rule=opp_dst_constraints_rule)

# %% [markdown]
# # QB and 2 TE/WR from same team Constraint:
#
# The constraint `return model1.qb[i] * 2 <= total_te_wr_same_team` is checking if at least 2 WRs or TEs from the same team as the selected QB are included in the lineup. Let's break down the explanation:
#
# - `model1.qb[i]` is a binary variable that equals 1 if the QB at index `i` is selected and 0 otherwise.
# - `total_te_wr_same_team` is the sum of binary variables representing the WRs and TEs from the same team as the QB. It counts the number of WRs and TEs selected from the QB's team.
#
# When evaluating the constraint, we consider the following scenarios:
#
# 1. If `model1.qb[i]` is 0 (QB not selected), the constraint is satisfied because there is no requirement for WRs or TEs from the QB's team.
#
# 2. If `model1.qb[i]` is 1 (QB selected), the constraint checks if the number of WRs and TEs from the QB's team (`total_te_wr_same_team`) is at least 2. If the condition `model1.qb[i] * 2 <= total_te_wr_same_team` holds true, it means that there are at least 2 WRs or TEs from the QB's team in the lineup, satisfying the stacking requirement. If the condition is not met, it indicates that there are fewer than 2 WRs or TEs from the QB's team, violating the stacking constraint.
#
# By including this constraint, the optimization model ensures that if a QB is selected, there are enough WRs or TEs from the same team to support the stacking strategy. This encourages the selection of QB-WR/TE combinations that have the potential for increased scoring synergy based on their team dynamics and on-field performance.

# %% [markdown]
# # Opposing DST constraint
#
# The constraint `return model1.qb[i] + opponent_dst_selected <= 1` is checking if the selected QB's opponent DST is included in the lineup, and if so, it ensures that this combination is not allowed. Let me explain it further.
#
# - `model1.qb[i]` is a binary variable that equals 1 if the QB at index `i` is selected and 0 otherwise.
# - `opponent_dst_selected` is a sum of binary variables representing the DSTs from the opponent team of the QB at index `i`. It equals 1 if any opponent DST is selected and 0 otherwise.
#
# When adding these two values together, we get the following possible scenarios:
#
# 1. If `model1.qb[i]` is 0 (QB not selected), the sum will always be less than or equal to 1, regardless of the value of `opponent_dst_selected`. This means that the constraint will hold true and won't affect the decision in this case.
#
# 2. If `model1.qb[i]` is 1 (QB selected) and `opponent_dst_selected` is 0 (opponent DST not selected), the sum is 1, which is less than or equal to 1. In this case, the constraint holds true and allows this combination.
#
# 3. If `model1.qb[i]` is 1 (QB selected) and `opponent_dst_selected` is 1 (opponent DST selected), the sum is 2, which is not less than or equal to 1. In this case, the constraint is not satisfied, and this combination is not allowed.
#
# So, the constraint ensures that the selected QB's opponent DST is not selected by not allowing the combinations where both the QB and its opponent DST are selected (the sum would be equal to 2).

# %%
SolverFactory('cbc').solve(model1, tee=True).write()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Feb  3 2023
#
# command line - /content/bin/cbc -printingOptions all -import /tmp/tmpm57s7b29.pyomo.lp -stat=1 -solve -solu /tmp/tmpm57s7b29.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
#  CoinLpIO::readLp(): Maximization problem reformulated as minimization
# Coin0009I Switching back to maximization to get correct duals etc
# Presolve 127 (-3) rows, 816 (-1) columns and 2510 (-1633) elements
# Statistics for presolved model
# Original problem has 816 integers (816 of which binary)
# Presolved problem has 816 integers (816 of which binary)
# ==== 4 zero objective 254 different
# ==== absolute objective values 254 different
# ==== for integers 4 zero objective 254 different
# ==== for integers absolute objective values 254 different
# ===== end objective counts
#
#
# Problem has 127 rows, 816 columns (812 with objective) and 2510 elements
# Column breakdown:
# 0 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 816 of type 0.0->1.0
# Row breakdown:
# 0 of type E 0.0, 4 of type E 1.0, 0 of type E -1.0,
# 2 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 60 of type L 0.0, 60 of type L 1.0,
# 1 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 166.068 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 60 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0004I processed model has 90 rows, 353 columns (353 integer (336 of which binary)) and 1659 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.27731
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. -162.682 iterations 14
# Cbc0038I Solution found of -162.682
# Cbc0038I Cleaned solution of -162.682
# Cbc0038I Before mini branch and bound, 347 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 90 rows 353 columns, reduced to 2 rows 2 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -163.021
# Cbc0038I Reduced cost fixing fixed 244 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.32774 (6) obj. -163.021 iterations 16
# Cbc0038I Pass   3: suminf.    0.32774 (6) obj. -163.021 iterations 9
# Cbc0038I Pass   4: suminf.    1.41284 (4) obj. -163.021 iterations 5
# Cbc0038I Pass   5: suminf.    0.89241 (2) obj. -163.021 iterations 3
# Cbc0038I Pass   6: suminf.    0.44828 (2) obj. -164.463 iterations 11
# Cbc0038I Pass   7: suminf.    0.65347 (2) obj. -163.021 iterations 5
# Cbc0038I Pass   8: suminf.    1.00000 (3) obj. -163.021 iterations 7
# Cbc0038I Pass   9: suminf.    1.00000 (3) obj. -163.021 iterations 5
# Cbc0038I Pass  10: suminf.    0.86957 (2) obj. -163.88 iterations 3
# Cbc0038I Pass  11: suminf.    0.50883 (4) obj. -163.021 iterations 7
# Cbc0038I Pass  12: suminf.    1.82701 (6) obj. -163.021 iterations 10
# Cbc0038I Pass  13: suminf.    1.13586 (4) obj. -163.021 iterations 7
# Cbc0038I Pass  14: suminf.    1.13586 (4) obj. -163.021 iterations 2
# Cbc0038I Pass  15: suminf.    1.38948 (5) obj. -163.021 iterations 6
# Cbc0038I Pass  16: suminf.    2.24813 (7) obj. -163.021 iterations 6
# Cbc0038I Pass  17: suminf.    1.04050 (4) obj. -163.021 iterations 5
# Cbc0038I Pass  18: suminf.    2.22695 (7) obj. -163.021 iterations 13
# Cbc0038I Pass  19: suminf.    1.00000 (2) obj. -163.061 iterations 8
# Cbc0038I Pass  20: suminf.    1.00000 (2) obj. -163.061 iterations 1
# Cbc0038I Pass  21: suminf.    1.00587 (4) obj. -163.021 iterations 1
# Cbc0038I Pass  22: suminf.    1.84150 (5) obj. -163.021 iterations 4
# Cbc0038I Pass  23: suminf.    0.40978 (6) obj. -163.021 iterations 12
# Cbc0038I Pass  24: suminf.    0.10345 (2) obj. -163.291 iterations 9
# Cbc0038I Pass  25: suminf.    0.14187 (2) obj. -163.021 iterations 6
# Cbc0038I Pass  26: suminf.    1.00000 (3) obj. -163.021 iterations 10
# Cbc0038I Pass  27: suminf.    1.00000 (3) obj. -163.021 iterations 5
# Cbc0038I Pass  28: suminf.    0.96000 (2) obj. -165.196 iterations 5
# Cbc0038I Pass  29: suminf.    0.01413 (4) obj. -163.021 iterations 6
# Cbc0038I Pass  30: suminf.    1.55289 (6) obj. -163.021 iterations 10
# Cbc0038I Pass  31: suminf.    1.09498 (5) obj. -163.021 iterations 11
# Cbc0038I Rounding solution of -162.964 is better than previous of -162.682
#
# Cbc0038I Before mini branch and bound, 328 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 90 rows 353 columns, reduced to 9 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from -162.964 to -163.545 (0.06 seconds)
# Cbc0038I Round again with cutoff of -164.05
# Cbc0038I Reduced cost fixing fixed 288 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.75472 (4) obj. -164.588 iterations 4
# Cbc0038I Pass  32: suminf.    0.39995 (5) obj. -164.05 iterations 12
# Cbc0038I Pass  33: suminf.    0.69248 (2) obj. -164.05 iterations 7
# Cbc0038I Pass  34: suminf.    0.44828 (2) obj. -164.463 iterations 7
# Cbc0038I Pass  35: suminf.    0.50706 (2) obj. -164.05 iterations 7
# Cbc0038I Pass  36: suminf.    2.38874 (8) obj. -164.05 iterations 14
# Cbc0038I Pass  37: suminf.    1.58333 (6) obj. -164.05 iterations 10
# Cbc0038I Pass  38: suminf.    1.28784 (5) obj. -164.05 iterations 2
# Cbc0038I Pass  39: suminf.    0.39184 (3) obj. -164.05 iterations 8
# Cbc0038I Pass  40: suminf.    0.39205 (3) obj. -164.05 iterations 5
# Cbc0038I Pass  41: suminf.    0.40034 (2) obj. -164.05 iterations 7
# Cbc0038I Pass  42: suminf.    1.15769 (6) obj. -164.05 iterations 8
# Cbc0038I Pass  43: suminf.    0.98648 (4) obj. -164.05 iterations 3
# Cbc0038I Pass  44: suminf.    2.62382 (6) obj. -164.05 iterations 11
# Cbc0038I Pass  45: suminf.    1.46939 (4) obj. -164.892 iterations 9
# Cbc0038I Pass  46: suminf.    1.61119 (4) obj. -164.05 iterations 9
# Cbc0038I Pass  47: suminf.    0.89991 (5) obj. -164.05 iterations 16
# Cbc0038I Pass  48: suminf.    0.89991 (5) obj. -164.05 iterations 3
# Cbc0038I Pass  49: suminf.    0.35340 (2) obj. -164.05 iterations 7
# Cbc0038I Pass  50: suminf.    0.27839 (3) obj. -164.05 iterations 6
# Cbc0038I Pass  51: suminf.    0.35340 (2) obj. -164.05 iterations 6
# Cbc0038I Pass  52: suminf.    1.56388 (6) obj. -164.05 iterations 15
# Cbc0038I Pass  53: suminf.    0.70169 (4) obj. -164.05 iterations 5
# Cbc0038I Pass  54: suminf.    0.70169 (4) obj. -164.05 iterations 2
# Cbc0038I Pass  55: suminf.    2.86134 (6) obj. -164.05 iterations 11
# Cbc0038I Pass  56: suminf.    1.50741 (5) obj. -164.05 iterations 7
# Cbc0038I Pass  57: suminf.    0.99428 (6) obj. -164.05 iterations 7
# Cbc0038I Pass  58: suminf.    0.99428 (6) obj. -164.05 iterations 6
# Cbc0038I Pass  59: suminf.    1.29986 (4) obj. -164.05 iterations 5
# Cbc0038I Pass  60: suminf.    0.99428 (6) obj. -164.05 iterations 11
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 331 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 90 rows 353 columns, reduced to 7 rows 16 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of -163.545 - took 0.06 seconds
# Cbc0012I Integer solution of -163.54546 found by feasibility pump after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0031I 6 added rows had average density of 77.5
# Cbc0013I At root node, 6 cuts changed objective from -166.06822 to -164.5951 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 47.8 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 5 row cuts average 24.8 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 5 row cuts average 5.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 67 row cuts average 30.1 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 97.8 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -163.54546 best solution, best possible -164.58262 (0.14 seconds)
# Cbc0012I Integer solution of -163.64176 found by rounding after 125 iterations and 4 nodes (0.16 seconds)
# Cbc0001I Search completed - best objective -163.6417631102362, took 128 iterations and 4 nodes (0.16 seconds)
# Cbc0032I Strong branching done 34 times (136 iterations), fathomed 0 nodes and fixed 4 variables
# Cbc0035I Maximum depth 1, 326 variables fixed on reduced cost
# Cuts at root node changed objective from -166.068 to -164.583
# Probing was tried 19 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Gomory was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 17 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 17 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 17 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 17 times and created 67 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# ZeroHalf was tried 17 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
#
# Result - Optimal solution found
#
# Objective value:                163.64176311
# Enumerated nodes:               4
# Total iterations:               128
# Time (CPU seconds):             0.17
# Time (Wallclock seconds):       0.33
#
# Total time (CPU seconds):       0.18   (Wallclock seconds):       0.35
#
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 163.64176311
#   Upper bound: 163.64176311
#   Number of objectives: 1
#   Number of constraints: 127
#   Number of variables: 816
#   Number of binary variables: 816
#   Number of integer variables: 816
#   Number of nonzeros: 812
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   User time: -1.0
#   System time: 0.18
#   Wallclock time: 0.35
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 4
#       Number of created subproblems: 4
#     Black box:
#       Number of iterations: 128
#   Error rc: 0
#   Time: 0.39017248153686523
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
selected_team_model1 = pd.DataFrame(columns=['Position', 'Name', 'Team', 'Opponent', 'Projected Points', 'Salary'])

# Add selected players to the DataFrame
for position, var_list in [('QB', model1.qb), ('RB', model1.rb), ('WR', model1.wr), ('TE', model1.te), ('DST', model1.dst), ('FLEX', model1.flex)]:
    for i in range(len(var_list)):
        if var_list[i].value == 1:
            data = None
            if position == 'QB':
                data = qb_data.iloc[i]
            elif position == 'RB':
                data = rb_data.iloc[i]
            elif position == 'WR':
                data = wr_data.iloc[i]
            elif position == 'TE':
                data = te_data.iloc[i]
            elif position == 'DST':
                data = dst_data.iloc[i]
            elif position == 'FLEX':
                data = flex_data.iloc[i]

            selected_team_model1 = selected_team_model1.append({
                'Position': position,
                'Name': data['Name'],
                'Team': data['Team'],
                'Opponent': data.get('Opp', ''),
                'Projected Points': data['SS Proj'],
                'Salary': data['Salary']
            }, ignore_index=True)

# Display the DataFrame as a table
print(f"Total points: {model1.total_points()}")
print("Team_Selection:", '\n\n', selected_team_model1, '\n\n')
# Out:
# Total points: 163.64176311023618
# Team_Selection:
#
#    Position              Name Team Opponent  Projected Points Salary
# 0       QB      Kyler Murray  ARI      PHI         26.894900   7000
# 1       RB      Alvin Kamara   NO       KC         25.160700   7400
# 2       RB      Tony Pollard  DAL       SF         20.983200   5200
# 3       WR   DeAndre Hopkins  ARI      PHI         20.023600   7900
# 4       WR       T.Y. Hilton  IND      HOU         15.557500   5500
# 5       WR  Emmanuel Sanders   NO       KC         15.505900   4200
# 6       TE   Darrell Daniels  ARI      PHI          8.145863   2500
# 7      DST        Cardinals   ARI      PHI          6.209400   2900
# 8     FLEX      Alvin Kamara   NO       KC         25.160700   7400
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
# <ipython-input-13-4171b776dced>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_team_model1 = selected_team_model1.append({
